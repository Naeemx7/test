# %%
def calculate(x, y, op):
    if op == '1':
        return x + y
    elif op == '2':
        return x - y
    elif op == '3':
        return x * y
    elif op == '4':
        return x / y if y != 0 else None
    else:
        return None

while True:
    print("Select operation:")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")
    print("5. Exit")

    choice = input("Enter choice (1/2/3/4/5): ")

    if choice == '5':
        print("Exiting the calculator program.")
        break

    if choice in ['1', '2', '3', '4']:
        num1 = float(input("Enter first number: "))
        num2 = float(input("Enter second number: "))
        
        result = calculate(num1, num2, choice)
        
        if result is None:
            print("Error: Invalid operation")
        elif choice == '4' and result is None:
            print("Error: Division by zero")
        elif result.is_integer():  # Check if the result is a whole number
            print("Result:", int(result))
        else:
            print("Result:", result)
    else:
        print("Error: Invalid choice")
# Out:
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# Enter choice (1/2/3/4/5): 4
# Enter first number: 1
# Enter second number: 2
# Result: 0.5
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 21
#      18 print("4. Divide")
#      19 print("5. Exit")
# ---> 21 choice = input("Enter choice (1/2/3/4/5): ")
#      23 if choice == '5':
#      24     print("Exiting the calculator program.")
#
# File ~/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# -> 1175 return self._input_request(
#    1176     str(prompt),
# ...

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

while True:
    expression = input("Enter an expression (e.g., 2 + 3, 5 * 6), or 'exit' to quit: ")
    
    if expression.lower() == 'exit':
        print("Exiting the calculator program.")
        break
    
    try:
        parts = expression.split()
        num1 = float(parts[0])
        operator = parts[1]
        num2 = float(parts[2])
        
        if operator == '+':
            result = add(num1, num2)
        elif operator == '-':
            result = subtract(num1, num2)
        elif operator == '*':
            result = multiply(num1, num2)
        else:
            result = "Error: Invalid operator"
        
        print("Result:", result)
    except (ValueError, IndexError):
        print("Error: Invalid input")

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

while True:
    expression = input("Enter an expression (e.g., 2 + 3, 5 * 6), or 'exit' to quit: ")
    
    if expression.lower() == 'exit':
        print("Exiting the calculator program.")
        break
    
    try:
        parts = expression.split()
        num1 = float(parts[0])
        operator = parts[1]
        num2 = float(parts[2])
        
        if operator == '+':
            result = add(num1, num2)
        elif operator == '-':
            result = subtract(num1, num2)
        elif operator == '*':
            result = multiply(num1, num2)
        else:
            result = "Error: Invalid operator"
        
        print("Result:", result)
    except (ValueError, IndexError):
        print("Error: Invalid input")
# Out:
# Enter an expression (e.g., 2 + 3, 5 * 6), or 'exit' to quit: 5*10
# Error: Invalid input
# Enter an expression (e.g., 2 + 3, 5 * 6), or 'exit' to quit: 5+2
# Error: Invalid input
# Enter an expression (e.g., 2 + 3, 5 * 6), or 'exit' to quit: exit
# Exiting the calculator program.

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

while True:
    expression = input("Enter an expression (e.g., 2 + 3, 5 * 6), or 'exit' to quit: ")
    
    if expression.lower() == 'exit':
        print("Exiting the calculator program.")
        break
    
    try:
        parts = expression.split()
        num1 = float(parts[0])
        operator = parts[1]
        num2 = float(parts[2])
        
        if operator == '+':
            result = add(num1, num2)
        elif operator == '-':
            result = subtract(num1, num2)
        elif operator == '*':
            result = multiply(num1, num2)
        else:
            result = "Error: Invalid operator"
        
        print("Result:", result)
    except (ValueError, IndexError):
        print("Error: Invalid input")
# Out:
# Enter an expression (e.g., 2 + 3, 5 * 6), or 'exit' to quit: 2
# Error: Invalid input
# Enter an expression (e.g., 2 + 3, 5 * 6), or 'exit' to quit: 2+3
# Error: Invalid input
# Enter an expression (e.g., 2 + 3, 5 * 6), or 'exit' to quit: 2 + 3
# Result: 5.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 11
#       8     return x * y
#      10 while True:
# ---> 11     expression = input("Enter an expression (e.g., 2 + 3, 5 * 6), or 'exit' to quit: ")
#      13     if expression.lower() == 'exit':
#      14         print("Exiting the calculator program.")
#
# File ~/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# ...

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

while True:
    expression = input("Enter an expression (e.g., 2+3, 5*6), or 'exit' to quit: ")
    
    if expression.lower() == 'exit':
        print("Exiting the calculator program.")
        break
    
    operators = ['+', '-', '*']
    operator = None
    
    for op in operators:
        if op in expression:
            operator = op
            break
    
    if operator:
        parts = expression.split(operator)
        try:
            num1 = float(parts[0])
            num2 = float(parts[1])
            
            if operator == '+':
                result = add(num1, num2)
            elif operator == '-':
                result = subtract(num1, num2)
            elif operator == '*':
                result = multiply(num1, num2)
            
            print("Result:", result)
        except ValueError:
            print("Error: Invalid input")
    else:
        print("Error: Invalid operator")
# Out:
# Enter an expression (e.g., 2+3, 5*6), or 'exit' to quit: 3+2
# Result: 5.0
# Enter an expression (e.g., 2+3, 5*6), or 'exit' to quit: 2+9
# Result: 11.0
# Enter an expression (e.g., 2+3, 5*6), or 'exit' to quit: 2/12
# Error: Invalid operator
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 11
#       8     return x * y
#      10 while True:
# ---> 11     expression = input("Enter an expression (e.g., 2+3, 5*6), or 'exit' to quit: ")
#      13     if expression.lower() == 'exit':
#      14         print("Exiting the calculator program.")
#
# File ~/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# ...

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        return "Error: Division by zero"
    else:
        return x / y

while True:
    expression = input("Enter an expression (e.g., 2+3, 5*6, 10/2), or 'exit' to quit: ")
    
    if expression.lower() == 'exit':
        print("Exiting the calculator program.")
        break
    
    operators = ['+', '-', '*', '/']
    operator = None
    
    for op in operators:
        if op in expression:
            operator = op
            break
    
    if operator:
        parts = expression.split(operator)
        try:
            num1 = float(parts[0])
            num2 = float(parts[1])
            
            if operator == '+':
                result = add(num1, num2)
            elif operator == '-':
                result = subtract(num1, num2)
            elif operator == '*':
                result = multiply(num1, num2)
            elif operator == '/':
                result = divide(num1, num2)
            
            print("Result:", result)
        except ValueError:
            print("Error: Invalid input")
    else:
        print("Error: Invalid operator")
# Out:
# Enter an expression (e.g., 2+3, 5*6, 10/2), or 'exit' to quit: 10/1
# Result: 10.0
# Enter an expression (e.g., 2+3, 5*6, 10/2), or 'exit' to quit: 10/0
# Result: Error: Division by zero
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 17
#      14         return x / y
#      16 while True:
# ---> 17     expression = input("Enter an expression (e.g., 2+3, 5*6, 10/2), or 'exit' to quit: ")
#      19     if expression.lower() == 'exit':
#      20         print("Exiting the calculator program.")
#
# File ~/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# -> 1175 return self._input_request(
#    1176     str(prompt),
# ...

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        return "Error: Division by zero"
    elif x % y == 0:
        return int(x / y)
    else:
        return x / y

while True:
    expression = input("Enter an expression (e.g., 2+3, 5*6, 10/2), or 'exit' to quit: ")
    
    if expression.lower() == 'exit':
        print("Exiting the calculator program.")
        break
    
    operators = ['+', '-', '*', '/']
    operator = None
    
    for op in operators:
        if op in expression:
            operator = op
            break
    
    if operator:
        parts = expression.split(operator)
        try:
            num1 = float(parts[0])
            num2 = float(parts[1])
            
            if operator == '+':
                result = add(num1, num2)
            elif operator == '-':
                result = subtract(num1, num2)
            elif operator == '*':
                result = multiply(num1, num2)
            elif operator == '/':
                result = divide(num1, num2)
            
            print("Result:", result)
        except ValueError:
            print("Error: Invalid input")
    else:
        print("Error: Invalid operator")
# Out:
# Enter an expression (e.g., 2+3, 5*6, 10/2), or 'exit' to quit: 2+34
# Result: 36.0
# Enter an expression (e.g., 2+3, 5*6, 10/2), or 'exit' to quit: exit
# Exiting the calculator program.

# %%
def prompt_menu():
    a = float(input("Enter the first number: "))
    b = float(input("Enter the second number: "))
    print("""
Choose an operation from the list:
1. Addition
2. Subtraction
3. Multiplication
4. Exponentiation
5. Division
6. Division with remainder
    """)
    op = int(input("Enter the choice number: "))
    return a, b, op

def calculate():
    a, b, op = prompt_menu()
    if op == 1:
        print("Sum: {} + {} = {}".format(a,b,a+b))
    elif op == 2:
        print("Difference: {} - {} = {}".format(a,b,a-b))
    elif op == 3:
        print("Product: {} * {} = {}".format(a,b,a*b))
    elif op == 4:
        print("Power: {}^{} = {}".format(a,b,a**b))
    elif op == 5:
        try:
            print("Quotient: {} / {} = {}".format(a,b,a/b))
        except:
            print("Division by 0 not possible!")
    elif op == 6:
        try:
            print("Division with remainder: {} / {} = {} Remainder: {}".format(a,b,a//b,a%b))
        except:
            print("Divsion by 0 not possible!")
    else:
        print("No such choice!")
    loop()

def loop():
    choice = input("Do you want to continue? (Y,N): ")
    if choice.upper() == "Y":
        calculate()
    elif choice.upper() == "N":
        print("Goodbye!")
    else:
        print("Invalid input!")
        loop()

calculate()
# Out:
# Enter the first number: 2
# Enter the second number: 4
#
# Choose an operation from the list:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Exponentiation
# 5. Division
# 6. Division with remainder
#
# Enter the choice number: 1
# Sum: 2.0 + 4.0 = 6.0
# Do you want to continue? (Y,N): y
# Enter the first number: 50
# Enter the second number: 0
#
# Choose an operation from the list:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Exponentiation
# 5. Division
# 6. Division with remainder
#
# Enter the choice number: 6
# Divsion by 0 not possible!
# Do you want to continue? (Y,N): t
# Invalid input!
# Do you want to continue? (Y,N): t
# Invalid input!
# Do you want to continue? (Y,N): y
# Enter the first number: 1231321321321
# Enter the second number: 32132132132132131321
#
# Choose an operation from the list:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Exponentiation
# 5. Division
# 6. Division with remainder
#
# Enter the choice number: 5
# ...

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        raise ValueError("Division by zero is not allowed")
    return x / y

while True:
    print("Select operation:")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")
    print("5. Exit")

    choice = input("Enter choice (1/2/3/4/5): ")

    if choice == '5':
        print("Exiting the calculator")
        break

    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    if choice == '1':
        print("Result:", add(num1, num2))
    elif choice == '2':
        print("Result:", subtract(num1, num2))
    elif choice == '3':
        print("Result:", multiply(num1, num2))
    elif choice == '4':
        try:
            print("Result:", divide(num1, num2))
        except ValueError as e:
            print("Error:", e)
    else:
        print("Invalid choice")
# Out:
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# Enter choice (1/2/3/4/5): 1
# Enter first number: 14
# Enter second number: 21
# Result: 35.0
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# Enter choice (1/2/3/4/5): 4
# Enter first number: 15
# Enter second number: 0
# Error: Division by zero is not allowed
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# Enter choice (1/2/3/4/5): 5
# Exiting the calculator

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        raise ValueError("Division by zero is not allowed")
    return x / y

while True:
    print("Select operation:")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")
    print("5. Exit")

    choice = input("Enter choice (1/2/3/4/5): ")

    if choice == '5':
        print("Exiting the calculator")
        break

    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    if choice == '1':
        result = add(num1, num2)
    elif choice == '2':
        result = subtract(num1, num2)
    elif choice == '3':
        result = multiply(num1, num2)
    elif choice == '4':
        try:
            result = divide(num1, num2)
        except ValueError as e:
            print("Error:", e)
            continue
    else:
        print("Invalid choice")
        continue

    if result >= 0 and result.is_integer():
        print("Result:", int(result))
    else:
        print("Result:", result)
# Out:
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# Enter choice (1/2/3/4/5): 2
# Enter first number: 5
# Enter second number: 5
# Result: 0
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# Enter choice (1/2/3/4/5): 1
# Enter first number: 123
# Enter second number: 55
# Result: 178
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# Enter choice (1/2/3/4/5): 4
# Enter first number: 51
# Enter second number: 12
# Result: 4.25
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Exit
# Enter choice (1/2/3/4/5): 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 29
#      26     print("Exiting the calculator")
#      27     break
# ---> 29 num1 = float(input("Enter first number: "))
#      30 num2 = float(input("Enter second number: "))
# ...

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        raise ValueError("Division by zero is not allowed")
    return x / y

while True:
    print("╔════════════════════════════╗")
    print("║        Calculator          ║")
    print("╠════════════════════════════╣")
    print("║ Options:                   ║")
    print("║   1. Add                   ║")
    print("║   2. Subtract              ║")
    print("║   3. Multiply              ║")
    print("║   4. Divide                ║")
    print("║   5. Exit                  ║")
    print("╚════════════════════════════╝")

    choice = input("Enter choice (1/2/3/4/5): ")

    if choice == '5':
        print("Exiting the calculator")
        break

    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    if choice == '1':
        result = add(num1, num2)
        operation = '+'
    elif choice == '2':
        result = subtract(num1, num2)
        operation = '-'
    elif choice == '3':
        result = multiply(num1, num2)
        operation = '*'
    elif choice == '4':
        try:
            result = divide(num1, num2)
            operation = '/'
        except ValueError as e:
            print("Error:", e)
            continue
    else:
        print("Invalid choice")
        continue

    print(f"Result: {num1} {operation} {num2} = {result:.2f}" if isinstance(result, float) else f"Result: {num1} {operation} {num2} = {int(result)}")
# Out:
# ╔════════════════════════════╗
# ║        Calculator          ║
# ╠════════════════════════════╣
# ║ Options:                   ║
# ║   1. Add                   ║
# ║   2. Subtract              ║
# ║   3. Multiply              ║
# ║   4. Divide                ║
# ║   5. Exit                  ║
# ╚════════════════════════════╝
# Enter choice (1/2/3/4/5): 1
# Enter first number: 2
# Enter second number: 5
# Result: 2.0 + 5.0 = 7.00
# ╔════════════════════════════╗
# ║        Calculator          ║
# ╠════════════════════════════╣
# ║ Options:                   ║
# ║   1. Add                   ║
# ║   2. Subtract              ║
# ║   3. Multiply              ║
# ║   4. Divide                ║
# ║   5. Exit                  ║
# ╚════════════════════════════╝
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 27
#      24 print("║   5. Exit                  ║")
# ...

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        raise ValueError("Division by zero is not allowed")
    return x / y

while True:
    print("╔════════════════════════════╗")
    print("║        Calculator          ║")
    print("╠════════════════════════════╣")
    print("║ Options:                   ║")
    print("║   1. Add                   ║")
    print("║   2. Subtract              ║")
    print("║   3. Multiply              ║")
    print("║   4. Divide                ║")
    print("║   5. Exit                  ║")
    print("╚════════════════════════════╝")

    choice = input("Enter choice (1/2/3/4/5): ")

    if choice == '5':
        print("Exiting the calculator")
        break

    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    if choice == '1':
        result = add(num1, num2)
        operation = '+'
    elif choice == '2':
        result = subtract(num1, num2)
        operation = '-'
    elif choice == '3':
        result = multiply(num1, num2)
        operation = '*'
    elif choice == '4':
        try:
            result = divide(num1, num2)
            operation = '/'
        except ValueError as e:
            print("Error:", e)
            continue
    else:
        print("Invalid choice")
        continue

    if result >= 0 and result.is_integer():
        print(f"Result: {num1} {operation} {num2} = {int(result)}")
    else:
        print(f"Result: {num1} {operation} {num2} = {result:.2f}")
# Out:
# ╔════════════════════════════╗
# ║        Calculator          ║
# ╠════════════════════════════╣
# ║ Options:                   ║
# ║   1. Add                   ║
# ║   2. Subtract              ║
# ║   3. Multiply              ║
# ║   4. Divide                ║
# ║   5. Exit                  ║
# ╚════════════════════════════╝
# Enter choice (1/2/3/4/5): 1
# Enter first number: 2
# Enter second number: 5
# Result: 2.0 + 5.0 = 7
# ╔════════════════════════════╗
# ║        Calculator          ║
# ╠════════════════════════════╣
# ║ Options:                   ║
# ║   1. Add                   ║
# ║   2. Subtract              ║
# ║   3. Multiply              ║
# ║   4. Divide                ║
# ║   5. Exit                  ║
# ╚════════════════════════════╝
# Enter choice (1/2/3/4/5): 4
# Enter first number: 5
# Enter second number: 12
# Result: 5.0 / 12.0 = 0.42
# ╔════════════════════════════╗
# ║        Calculator          ║
# ╠════════════════════════════╣
# ...

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        raise ValueError("Division by zero is not allowed")
    return x / y

while True:
    print("╔════════════════════════════╗")
    print("║   🐟 Naeem  Calculator 🐟   ║")
    print("╠════════════════════════════╣")
    print("║ Options:                   ║")
    print("║   1. Add                   ║")
    print("║   2. Subtract              ║")
    print("║   3. Multiply              ║")
    print("║   4. Divide                ║")
    print("║   5. Exit                  ║")
    print("╚════════════════════════════╝")

    choice = input("Enter choice (1/2/3/4/5): ")

    if choice == '5':
        print("Exiting Naeem's Fish Calculator")
        break

    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    if choice == '1':
        result = add(num1, num2)
        operation = '+'
    elif choice == '2':
        result = subtract(num1, num2)
        operation = '-'
    elif choice == '3':
        result = multiply(num1, num2)
        operation = '*'
    elif choice == '4':
        try:
            result = divide(num1, num2)
            operation = '/'
        except ValueError as e:
            print("Error:", e)
            continue
    else:
        print("Invalid choice")
        continue

    if result >= 0 and result.is_integer():
        print(f"Result: {num1} {operation} {num2} = {int(result)}")
    else:
        print(f"Result: {num1} {operation} {num2} = {result:.2f}")
# Out:
# ╔════════════════════════════╗
# ║   🐟 Naeem  Calculator 🐟   ║
# ╠════════════════════════════╣
# ║ Options:                   ║
# ║   1. Add                   ║
# ║   2. Subtract              ║
# ║   3. Multiply              ║
# ║   4. Divide                ║
# ║   5. Exit                  ║
# ╚════════════════════════════╝
# Enter choice (1/2/3/4/5): 1
# Enter first number: 11
# Enter second number: 4444
# Result: 11.0 + 4444.0 = 4455
# ╔════════════════════════════╗
# ║   🐟 Naeem  Calculator 🐟   ║
# ╠════════════════════════════╣
# ║ Options:                   ║
# ║   1. Add                   ║
# ║   2. Subtract              ║
# ║   3. Multiply              ║
# ║   4. Divide                ║
# ║   5. Exit                  ║
# ╚════════════════════════════╝
# Enter choice (1/2/3/4/5): 5
# Exiting Naeem's Fish Calculator

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        raise ValueError("Division by zero is not allowed")
    return x / y

while True:
    print("╔════════════════════════════╗")
    print("║  🐟 Naeem's Fish Calculator 🐟  ║")
    print("╠════════════════════════════╣")
    print("║ Options:                   ║")
    print("║   1. Add                   ║")
    print("║   2. Subtract              ║")
    print("║   3. Multiply              ║")
    print("║   4. Divide                ║")
    print("║   5. Exit                  ║")
    print("╚════════════════════════════╝")

    choice = input("Enter choice (1/2/3/4/5): ")

    if choice == '5':
        print("Exiting Naeem's Fish Calculator")
        break

    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    if choice == '1':
        result = add(num1, num2)
        operation = '+'
    elif choice == '2':
        result = subtract(num1, num2)
        operation = '-'
    elif choice == '3':
        result = multiply(num1, num2)
        operation = '*'
    elif choice == '4':
        try:
            result = divide(num1, num2)
            operation = '/'
        except ValueError as e:
            print("Error:", e)
            continue
    else:
        print("Invalid choice")
        continue

    if result.is_integer():
        print(f"Result: {num1} {operation} {num2} = {int(result)}")
    else:
        print(f"Result: {num1} {operation} {num2} = {result:.2f}")

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        raise ValueError("Division by zero is not allowed")
    return x / y

while True:
    print("╔════════════════════════════╗")
    print("║  🐟  Naeem  Calculator  🐟  ║")
    print("╠════════════════════════════╣")
    print("║ Options:                   ║")
    print("║   1. Add                   ║")
    print("║   2. Subtract              ║")
    print("║   3. Multiply              ║")
    print("║   4. Divide                ║")
    print("║   5. Exit                  ║")
    print("╚════════════════════════════╝")

    choice = input("Enter choice (1/2/3/4/5): ")

    if choice == '5':
        print("Exiting Naeem Calculator")
        break

    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    if choice == '1':
        result = add(num1, num2)
        operation = '+'
    elif choice == '2':
        result = subtract(num1, num2)
        operation = '-'
    elif choice == '3':
        result = multiply(num1, num2)
        operation = '*'
    elif choice == '4':
        try:
            result = divide(num1, num2)
            operation = '/'
        except ValueError as e:
            print("Error:", e)
            continue
    else:
        print("Invalid choice")
        continue

    if result.is_integer():
        print(f"Result: {int(num1)} {operation} {int(num2)} = {int(result)}")
    else:
        print(f"Result: {int(num1)} {operation} {int(num2)} = {result:.2f}")
# Out:
# ╔════════════════════════════╗
# ║  🐟  Naeem  Calculator  🐟  ║
# ╠════════════════════════════╣
# ║ Options:                   ║
# ║   1. Add                   ║
# ║   2. Subtract              ║
# ║   3. Multiply              ║
# ║   4. Divide                ║
# ║   5. Exit                  ║
# ╚════════════════════════════╝
# Enter choice (1/2/3/4/5): 4
# Enter first number: 4
# Enter second number: 1
# Result: 4 / 1 = 4
# ╔════════════════════════════╗
# ║  🐟  Naeem  Calculator  🐟  ║
# ╠════════════════════════════╣
# ║ Options:                   ║
# ║   1. Add                   ║
# ║   2. Subtract              ║
# ║   3. Multiply              ║
# ║   4. Divide                ║
# ║   5. Exit                  ║
# ╚════════════════════════════╝
# Enter choice (1/2/3/4/5): 5
# Exiting Naeem Calculator

# %%
def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        raise ValueError("Division by zero is not allowed")
    return x / y

while True:
    print("╔════════════════════════════╗")
    print("║  🐟  Naeem  Calculator  🐟 ║")
    print("╠════════════════════════════╣")
    print("║ Options:                   ║")
    print("║   1. Add                   ║")
    print("║   2. Subtract              ║")
    print("║   3. Multiply              ║")
    print("║   4. Divide                ║")
    print("║   5. Exit                  ║")
    print("╚════════════════════════════╝")

    choice = input("Enter choice (1/2/3/4/5): ")

    if choice == '5':
        print("Exiting Naeem Calculator")
        break

    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    if choice == '1':
        result = add(num1, num2)
        operation = '+'
    elif choice == '2':
        result = subtract(num1, num2)
        operation = '-'
    elif choice == '3':
        result = multiply(num1, num2)
        operation = '*'
    elif choice == '4':
        try:
            result = divide(num1, num2)
            operation = '/'
        except ValueError as e:
            print("Error:", e)
            continue
    else:
        print("Invalid choice")
        continue

    if result.is_integer():
        print(f"Result: {int(num1)} {operation} {int(num2)} = {int(result)}")
    else:
        print(f"Result: {int(num1)} {operation} {int(num2)} = {result:.2f}")
# Out:
# ╔════════════════════════════╗
# ║  🐟  Naeem  Calculator  🐟 ║
# ╠════════════════════════════╣
# ║ Options:                   ║
# ║   1. Add                   ║
# ║   2. Subtract              ║
# ║   3. Multiply              ║
# ║   4. Divide                ║
# ║   5. Exit                  ║
# ╚════════════════════════════╝
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 21
#      18 print("║   5. Exit                  ║")
#      19 print("╚════════════════════════════╝")
# ---> 21 choice = input("Enter choice (1/2/3/4/5): ")
#      23 if choice == '5':
#      24     print("Exiting Naeem Calculator")
#
# File ~/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
# ...

# %%
def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        raise ValueError("Division by zero is not allowed")
    return x / y

while True:
    print("╔════════════════════════════╗")
    print("║  🐟  Naeem  Calculator  🐟  ║")
    print("╠════════════════════════════╣")
    print("║ Options:                   ║")
    print("║   1. Add                   ║")
    print("║   2. Subtract              ║")
    print("║   3. Multiply              ║")
    print("║   4. Divide                ║")
    print("║   5. Exit                  ║")
    print("╚════════════════════════════╝")

    choice = input("Enter choice (1/2/3/4/5): ")

    if choice == '5':
        print("Exiting Naeem Calculator")
        break

    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    if choice == '1':
        result = add(num1, num2)
        operation = '+'
    elif choice == '2':
        result = subtract(num1, num2)
        operation = '-'
    elif choice == '3':
        result = multiply(num1, num2)
        operation = '*'
    elif choice == '4':
        try:
            result = divide(num1, num2)
            operation = '/'
        except ValueError as e:
            print("Error:", e)
            continue
    else:
        print("Invalid choice")
        continue

    if result.is_integer():
        print(f"Result: {int(num1)} {operation} {int(num2)} = {int(result)}")
    else:
        print(f"Result: {int(num1)} {operation} {int(num2)} = {result:.2f}")
# Out:
# ╔════════════════════════════╗
# ║  🐟  Naeem  Calculator  🐟  ║
# ╠════════════════════════════╣
# ║ Options:                   ║
# ║   1. Add                   ║
# ║   2. Subtract              ║
# ║   3. Multiply              ║
# ║   4. Divide                ║
# ║   5. Exit                  ║
# ╚════════════════════════════╝
# Enter choice (1/2/3/4/5): 1
# Enter first number: 15
# Enter second number: 5
# Result: 15 + 5 = 20
# ╔════════════════════════════╗
# ║  🐟  Naeem  Calculator  🐟  ║
# ╠════════════════════════════╣
# ║ Options:                   ║
# ║   1. Add                   ║
# ║   2. Subtract              ║
# ║   3. Multiply              ║
# ║   4. Divide                ║
# ║   5. Exit                  ║
# ╚════════════════════════════╝
# Enter choice (1/2/3/4/5): 5
# Exiting Naeem Calculator

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        raise ValueError("Division by zero is not allowed")
    return x / y

print("╔════════════════════════════╗")
print("║  🐟 Naeem's Fish Calculator 🐟  ║")
print("╚════════════════════════════╝")

while True:
    print("\nOptions:")
    print("   1. Add")
    print("   2. Subtract")
    print("   3. Multiply")
    print("   4. Divide")
    print("   5. Exit")

    choice = input("Enter choice (1/2/3/4/5): ")

    if choice == '5':
        print("Exiting Naeem's Fish Calculator")
        break

    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    if choice == '1':
        result = add(num1, num2)
        operation = '+'
    elif choice == '2':
        result = subtract(num1, num2)
        operation = '-'
    elif choice == '3':
        result = multiply(num1, num2)
        operation = '*'
    elif choice == '4':
        try:
            result = divide(num1, num2)
            operation = '/'
        except ValueError as e:
            print("Error:", e)
            continue
    else:
        print("Invalid choice")
        continue

    if result.is_integer():
        print(f"Result: {int(num1)} {operation} {int(num2)} = {int(result)}")
    else:
        print(f"Result: {int(num1)} {operation} {int(num2)} = {result:.2f}")
# Out:
# ╔════════════════════════════╗
# ║  🐟 Naeem's Fish Calculator 🐟  ║
# ╚════════════════════════════╝
#
# Options:
#    1. Add
#    2. Subtract
#    3. Multiply
#    4. Divide
#    5. Exit
# Enter choice (1/2/3/4/5): 1
# Enter first number: 1
# Enter second number: 5
# Result: 1 + 5 = 6
#
# Options:
#    1. Add
#    2. Subtract
#    3. Multiply
#    4. Divide
#    5. Exit
# Enter choice (1/2/3/4/5): 15
# Enter first number: 5
# Enter second number: 6
# Invalid choice
#
# Options:
#    1. Add
#    2. Subtract
#    3. Multiply
#    4. Divide
#    5. Exit
# Enter choice (1/2/3/4/5): 4
# Enter first number: 12
# Enter second number: 5
# Result: 12 / 5 = 2.40
#
# Options:
#    1. Add
#    2. Subtract
#    3. Multiply
#    4. Divide
#    5. Exit
